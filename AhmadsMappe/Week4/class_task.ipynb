# %%
# y = a * x + b

# %%
import matplotlib.pyplot as plt

# Define x and y points
x = [3, 6, 4, 5]
y = [0, -3, -1, -2]

# %%
plt.scatter(x, y)
plt.xlabel('x values')
plt.ylabel('y values')

# a is +3 (intercept)
# b is -1 (slope)
# Out:
# Text(0, 0.5, 'y values')
